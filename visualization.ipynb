# %%
#importing pandas 
import pandas as pd
#read data
file='SofwareDeveloperIncomeExpensesperUSACity.csv'
df=pd.read_csv(file)
df
# Out:
#     Unnamed: 0                                      Metro  \
# 0            0                               Columbus, OH
# 1            1                Seattle-Tacoma-Bellevue, WA
# 2            2          Charlotte-Concord-Gastonia, NC-SC
# 3            3                       Colorado Springs, CO
# 4            4                                 Dayton, OH
# ..         ...                                        ...
# 72          72                       Cleveland-Elyria, OH
# 73          73  Miami-Fort Lauderdale-West Palm Beach, FL
# 74          74  Miami-Fort Lauderdale-West Palm Beach, FL
# 75          75                                 Eugene, OR
# 76          76                         Urban Honolulu, HI
#
#     Mean Software Developer Salary (adjusted)  \
# 0                                    117552.0
# 1                                    117323.0
# 2                                    114122.0
# 3                                    112118.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Metro', 'Mean Software Developer Salary (adjusted)',
#        'Mean Software Developer Salary (unadjusted)',
#        'Mean Unadjusted Salary (all occupations)',
#        'Number of Software Developer Jobs', 'Median Home Price', 'City',
#        'Cost of Living avg', 'Rent avg', 'Cost of Living Plus Rent avg',
#        'Local Purchasing Power avg'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.title('Mean Salary against living cost', fontsize=25, color='red')
x=df['Mean Software Developer Salary (adjusted)']
y=df['Mean Unadjusted Salary (all occupations)']
plt.xlabel('Mean Software Developer Salary (adjusted)')
plt.ylabel('Mean Unadjusted Salary (all occupations)')
plt.plot(x,y)
plt.figure()
plt.show()

# %%
y=[20,40,10,70]
x=['Kogi','Niger','Beyelsa','Lagos']
plt.bar(x,y)
plt.show()

# %%
#loading rice production across different countries from 1961 to 2021
df=pd.read_csv('rice production across different countries from 1961 to 2021.csv')
df.columns
# Out:
# Index(['Area', 'Year', 'Unit', 'Value', 'Flag', 'Flag Description'], dtype='object')

# %%
#information about the data
df.describe()
# Out:
#               Year         Value
# count  7324.000000  7.324000e+03
# mean   1992.190470  5.593586e+06
# std      17.675328  2.439717e+07
# min    1961.000000  0.000000e+00
# 25%    1977.000000  1.409250e+04
# 50%    1993.000000  1.202430e+05
# 75%    2008.000000  9.817132e+05
# max    2021.000000  2.144299e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7324 entries, 0 to 7323
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Area              7324 non-null   object
#  1   Year              7324 non-null   int64
#  2   Unit              7324 non-null   object
#  3   Value             7324 non-null   float64
#  4   Flag              7324 non-null   object
#  5   Flag Description  7324 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 343.4+ KB

# %%
df2=df[['Area','Year','Value']]
#filtering for 2021
df2=df2.loc[df2['Year']==2021]
df2=df2.loc[df2['Area'].isin(['Angola', 'Brunei Darussalam','Belize'])]
df2
# Out:
#                   Area  Year    Value
# 243             Angola  2021  10514.0
# 547             Belize  2021  14990.0
# 852  Brunei Darussalam  2021   2675.0

# %%
x=df2['Area']
y=df2['Value']
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
#Analysing production in nigeria since 1960-2021
df3=df.loc[df['Area']=='Nigeria']
df3
# Out:
#          Area  Year    Unit       Value Flag Flag Description
# 4817  Nigeria  1961  tonnes    133000.0    A  Official figure
# 4818  Nigeria  1962  tonnes    257000.0    A  Official figure
# 4819  Nigeria  1963  tonnes    195000.0    A  Official figure
# 4820  Nigeria  1964  tonnes    220000.0    A  Official figure
# 4821  Nigeria  1965  tonnes    231000.0    A  Official figure
# ...       ...   ...     ...         ...  ...              ...
# 4873  Nigeria  2017  tonnes  10889549.0    A  Official figure
# 4874  Nigeria  2018  tonnes  10858537.0    A  Official figure
# 4875  Nigeria  2019  tonnes   8435510.0    A  Official figure
# 4876  Nigeria  2020  tonnes   8171800.0    A  Official figure
# 4877  Nigeria  2021  tonnes   8342000.0    A  Official figure
#
# [61 rows x 6 columns]

# %%
#plotting year against value
#Line Graph
x=df3['Year']
y=df3['Value']
plt.xlabel('Year')
plt.ylabel('Values')
plt.title('plotting year against value')
plt.plot(x,y)

# %%
#plotting year against value
#Bar graph
x=df3['Year']
y=df3['Value']
plt.xlabel('Year')
plt.ylabel('Values')
plt.title('plotting year against value')
plt.bar(x,y)
# Out:
# <BarContainer object of 61 artists>

# %%
print(df3.loc[df3['Value']==y.max()])
print('This shows that Nigeria had the highest production in 2017')
# Out:
#          Area  Year    Unit       Value Flag Flag Description
# 4873  Nigeria  2017  tonnes  10889549.0    A  Official figure
# This shows that Nigeria had the highest production in 2017
