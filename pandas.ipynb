# %%
#importing pandas 
import pandas as pd
#read data
file='SofwareDeveloperIncomeExpensesperUSACity.csv'
df=pd.read_csv(file)
df
# Out:
#     Unnamed: 0                                      Metro  \
# 0            0                               Columbus, OH
# 1            1                Seattle-Tacoma-Bellevue, WA
# 2            2          Charlotte-Concord-Gastonia, NC-SC
# 3            3                       Colorado Springs, CO
# 4            4                                 Dayton, OH
# ..         ...                                        ...
# 72          72                       Cleveland-Elyria, OH
# 73          73  Miami-Fort Lauderdale-West Palm Beach, FL
# 74          74  Miami-Fort Lauderdale-West Palm Beach, FL
# 75          75                                 Eugene, OR
# 76          76                         Urban Honolulu, HI
#
#     Mean Software Developer Salary (adjusted)  \
# 0                                    117552.0
# 1                                    117323.0
# 2                                    114122.0
# 3                                    112118.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 11 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Metro                                        77 non-null     object
#  1   Mean Software Developer Salary (adjusted)    77 non-null     float64
#  2   Mean Software Developer Salary (unadjusted)  77 non-null     float64
#  3   Mean Unadjusted Salary (all occupations)     77 non-null     float64
#  4   Number of Software Developer Jobs            77 non-null     float64
#  5   Median Home Price                            77 non-null     float64
#  6   City                                         77 non-null     object
#  7   Cost of Living avg                           77 non-null     float64
#  8   Rent avg                                     77 non-null     float64
# ...

# %%
#drop unnammed column
df=df.drop('Unnamed: 0',axis=1)

# %%
#Selecting some columns
df2=df[['Mean Software Developer Salary (adjusted)','City','Metro']]
df2
# Out:
#     Mean Software Developer Salary (adjusted)                  City  \
# 0                                    117552.0          Columbus, OH
# 1                                    117323.0           Seattle, WA
# 2                                    114122.0         Charlotte, NC
# 3                                    112118.0  Colorado Springs, CO
# 4                                    111616.0            Dayton, OH
# ..                                        ...                   ...
# 72                                    89040.0         Cleveland, OH
# 73                                    88249.0             Miami, FL
# 74                                    88249.0   Fort Lauderdale, FL
# 75                                    85912.0            Eugene, OR
# 76                                    72811.0          Honolulu, HI
#
#                                         Metro
# 0                                Columbus, OH
# 1                 Seattle-Tacoma-Bellevue, WA
# ...

# %%
#getting the 10 input
df.head(10)
# Out:
#                                Metro  \
# 0                       Columbus, OH
# 1        Seattle-Tacoma-Bellevue, WA
# 2  Charlotte-Concord-Gastonia, NC-SC
# 3               Colorado Springs, CO
# 4                         Dayton, OH
# 5          Greensboro-High Point, NC
# 6  San Francisco-Oakland-Hayward, CA
# 7  San Francisco-Oakland-Hayward, CA
# 8      San Antonio-New Braunfels, TX
# 9    Dallas-Fort Worth-Arlington, TX
#
#    Mean Software Developer Salary (adjusted)  \
# 0                                   117552.0
# 1                                   117323.0
# 2                                   114122.0
# 3                                   112118.0
# 4                                   111616.0
# 5                                   111050.0
# 6                                   111017.0
# 7                                   111017.0
# 8                                   110898.0
# 9                                   110891.0
#
# ...

# %%
#information about the data
df.describe()
# Out:
#        Mean Software Developer Salary (adjusted)  \
# count                                  77.000000
# mean                               100832.974026
# std                                  8064.298677
# min                                 72811.000000
# 25%                                 95308.000000
# 50%                                101256.000000
# 75%                                107170.000000
# max                                117552.000000
#
#        Mean Software Developer Salary (unadjusted)  \
# count                                    77.000000
# mean                                 101866.207792
# std                                   13926.636588
# min                                   80314.000000
# 25%                                   91976.000000
# 50%                                  100614.000000
# 75%                                  109503.000000
# max                                  142101.000000
#
#        Mean Unadjusted Salary (all occupations)  \
# ...

# %%
#shape of the data
df.shape
# Out:
# (77, 11)

# %%
df.columns
# Out:
# Index(['Metro', 'Mean Software Developer Salary (adjusted)',
#        'Mean Software Developer Salary (unadjusted)',
#        'Mean Unadjusted Salary (all occupations)',
#        'Number of Software Developer Jobs', 'Median Home Price', 'City',
#        'Cost of Living avg', 'Rent avg', 'Cost of Living Plus Rent avg',
#        'Local Purchasing Power avg'],
#       dtype='object')

# %%
#to drop column
df3=df.drop('Median Home Price',axis=1)
df3
# Out:
#                                         Metro  \
# 0                                Columbus, OH
# 1                 Seattle-Tacoma-Bellevue, WA
# 2           Charlotte-Concord-Gastonia, NC-SC
# 3                        Colorado Springs, CO
# 4                                  Dayton, OH
# ..                                        ...
# 72                       Cleveland-Elyria, OH
# 73  Miami-Fort Lauderdale-West Palm Beach, FL
# 74  Miami-Fort Lauderdale-West Palm Beach, FL
# 75                                 Eugene, OR
# 76                         Urban Honolulu, HI
#
#     Mean Software Developer Salary (adjusted)  \
# 0                                    117552.0
# 1                                    117323.0
# 2                                    114122.0
# 3                                    112118.0
# 4                                    111616.0
# ..                                        ...
# 72                                    89040.0
# ...

# %%
#remove row
df4=df.drop(1, axis=0)
df4
# Out:
#                                         Metro  \
# 0                                Columbus, OH
# 2           Charlotte-Concord-Gastonia, NC-SC
# 3                        Colorado Springs, CO
# 4                                  Dayton, OH
# 5                   Greensboro-High Point, NC
# ..                                        ...
# 72                       Cleveland-Elyria, OH
# 73  Miami-Fort Lauderdale-West Palm Beach, FL
# 74  Miami-Fort Lauderdale-West Palm Beach, FL
# 75                                 Eugene, OR
# 76                         Urban Honolulu, HI
#
#     Mean Software Developer Salary (adjusted)  \
# 0                                    117552.0
# 2                                    114122.0
# 3                                    112118.0
# 4                                    111616.0
# 5                                    111050.0
# ..                                        ...
# 72                                    89040.0
# ...

# %%
#drop na
df=df.dropna(axis=0)
df
# Out:
#                                         Metro  \
# 0                                Columbus, OH
# 1                 Seattle-Tacoma-Bellevue, WA
# 2           Charlotte-Concord-Gastonia, NC-SC
# 3                        Colorado Springs, CO
# 4                                  Dayton, OH
# ..                                        ...
# 72                       Cleveland-Elyria, OH
# 73  Miami-Fort Lauderdale-West Palm Beach, FL
# 74  Miami-Fort Lauderdale-West Palm Beach, FL
# 75                                 Eugene, OR
# 76                         Urban Honolulu, HI
#
#     Mean Software Developer Salary (adjusted)  \
# 0                                    117552.0
# 1                                    117323.0
# 2                                    114122.0
# 3                                    112118.0
# 4                                    111616.0
# ..                                        ...
# 72                                    89040.0
# ...

# %%
#import matplotlib for the plotting
import matplotlib.pyplot as plt

# %%
x=df['Mean Software Developer Salary (adjusted)']
y=df['Mean Unadjusted Salary (all occupations)']

# %%
plt.plot(x,y)
plt.show()
# plt.title('Mean Software Developer Salary (adjusted) against Mean Unadjusted Salary (all occupations)')
