# %%
#importing pandas 
import pandas as pd
#read data
file='SofwareDeveloperIncomeExpensesperUSACity.csv'
df=pd.read_csv(file)
df
# Out:
#     Unnamed: 0                                      Metro  \
# 0            0                               Columbus, OH
# 1            1                Seattle-Tacoma-Bellevue, WA
# 2            2          Charlotte-Concord-Gastonia, NC-SC
# 3            3                       Colorado Springs, CO
# 4            4                                 Dayton, OH
# ..         ...                                        ...
# 72          72                       Cleveland-Elyria, OH
# 73          73  Miami-Fort Lauderdale-West Palm Beach, FL
# 74          74  Miami-Fort Lauderdale-West Palm Beach, FL
# 75          75                                 Eugene, OR
# 76          76                         Urban Honolulu, HI
#
#     Mean Software Developer Salary (adjusted)  \
# 0                                    117552.0
# 1                                    117323.0
# 2                                    114122.0
# 3                                    112118.0
# ...
